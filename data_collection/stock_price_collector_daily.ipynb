# %%
'''
S&P500의 종목들의 2010년 이후 가격, 거래량 정보 추출
'''
import sqlite3
import pandas as pd
import yfinance as yf


conn = sqlite3.connect('Database/S&P500.db')
query = "SELECT * FROM stock"
stock = pd.read_sql_query(query, conn)
ticker_by_sector = stock.groupby(by='gics_sector')['symbol'].apply(list).to_dict()

conn.close()

# %%
''' 2010년 이후의 주가 데이터를 불러와서 DB에 저장 '''
import sqlite3
import pandas as pd


conn = sqlite3.connect('Database/S&P500.db')

for sector, tickers in ticker_by_sector.items():
    # 업종별로 주가 데이터를 가져옴
    daily_stock_price = yf.download(tickers, start='2010-01-01', interval="1d")
    for ticker in tickers:    
        # 업종의 일일 주가에서 특정 종목을 뽑아냄
        data = daily_stock_price.xs(ticker, level=1, axis=1)

        # 결측 행 제거 및 데이터를 가지고 있지 않은 ticker는 건너뜀
        data = data.dropna(axis=0)
        if data.size == 0:
            continue

        # 날짜를 인덱스에서 컬럼으로 옮기고, 날짜형으로 변경
        data = data.reset_index()
        data['Date'] = pd.to_datetime(data['Date'])
        
        # DB 네이밍 규칙에 따른 변환 (대문자->소문자, 공백->_)
        data.columns = data.columns.str.lower().str.replace(' ', '_')
        
        # 성능을 위한 종목, 업종명 삽입
        data.loc[ : , 'symbol'] = ticker
        data.loc[ : , 'gics_sector'] = sector
        data = pd.concat([data.iloc[ : , -2: ], data.iloc[ : , :-2]], axis=1)
    
        # DB에 추가
        data.to_sql('daily_stock_price', conn, if_exists='append', index=False)
        print(f"Sector : {sector}, Ticker : {ticker} - Saved to DB")
    
conn.close()
# Out:
# [*********************100%***********************]  22 of 22 completed
# Sector : Communication Services, Ticker : GOOGL - Saved to DB
# Sector : Communication Services, Ticker : GOOG - Saved to DB
# Sector : Communication Services, Ticker : T - Saved to DB
# Sector : Communication Services, Ticker : CHTR - Saved to DB
# Sector : Communication Services, Ticker : CMCSA - Saved to DB
# Sector : Communication Services, Ticker : EA - Saved to DB
# Sector : Communication Services, Ticker : FOXA - Saved to DB
# Sector : Communication Services, Ticker : FOX - Saved to DB
# Sector : Communication Services, Ticker : IPG - Saved to DB
# Sector : Communication Services, Ticker : LYV - Saved to DB
# Sector : Communication Services, Ticker : MTCH - Saved to DB
# Sector : Communication Services, Ticker : META - Saved to DB
# Sector : Communication Services, Ticker : NFLX - Saved to DB
# Sector : Communication Services, Ticker : NWSA - Saved to DB
# Sector : Communication Services, Ticker : NWS - Saved to DB
# Sector : Communication Services, Ticker : OMC - Saved to DB
# Sector : Communication Services, Ticker : PARA - Saved to DB
# Sector : Communication Services, Ticker : TMUS - Saved to DB
# Sector : Communication Services, Ticker : TTWO - Saved to DB
# Sector : Communication Services, Ticker : VZ - Saved to DB
# Sector : Communication Services, Ticker : DIS - Saved to DB
# Sector : Communication Services, Ticker : WBD - Saved to DB
# [*********************100%***********************]  50 of 50 completed
# Sector : Consumer Discretionary, Ticker : ABNB - Saved to DB
# Sector : Consumer Discretionary, Ticker : AMZN - Saved to DB
# Sector : Consumer Discretionary, Ticker : APTV - Saved to DB
# Sector : Consumer Discretionary, Ticker : AZO - Saved to DB
# Sector : Consumer Discretionary, Ticker : BBY - Saved to DB
# Sector : Consumer Discretionary, Ticker : BKNG - Saved to DB
# Sector : Consumer Discretionary, Ticker : BWA - Saved to DB
# Sector : Consumer Discretionary, Ticker : CZR - Saved to DB
# Sector : Consumer Discretionary, Ticker : KMX - Saved to DB
# Sector : Consumer Discretionary, Ticker : CCL - Saved to DB
# Sector : Consumer Discretionary, Ticker : CMG - Saved to DB
# Sector : Consumer Discretionary, Ticker : DRI - Saved to DB
# Sector : Consumer Discretionary, Ticker : DECK - Saved to DB
# Sector : Consumer Discretionary, Ticker : DPZ - Saved to DB
# Sector : Consumer Discretionary, Ticker : DHI - Saved to DB
# Sector : Consumer Discretionary, Ticker : EBAY - Saved to DB
# Sector : Consumer Discretionary, Ticker : EXPE - Saved to DB
# Sector : Consumer Discretionary, Ticker : F - Saved to DB
# Sector : Consumer Discretionary, Ticker : GRMN - Saved to DB
# Sector : Consumer Discretionary, Ticker : GM - Saved to DB
# Sector : Consumer Discretionary, Ticker : GPC - Saved to DB
# Sector : Consumer Discretionary, Ticker : HAS - Saved to DB
# Sector : Consumer Discretionary, Ticker : HLT - Saved to DB
# Sector : Consumer Discretionary, Ticker : HD - Saved to DB
# Sector : Consumer Discretionary, Ticker : LVS - Saved to DB
# Sector : Consumer Discretionary, Ticker : LEN - Saved to DB
# Sector : Consumer Discretionary, Ticker : LKQ - Saved to DB
# Sector : Consumer Discretionary, Ticker : LOW - Saved to DB
# Sector : Consumer Discretionary, Ticker : LULU - Saved to DB
# Sector : Consumer Discretionary, Ticker : MAR - Saved to DB
# Sector : Consumer Discretionary, Ticker : MCD - Saved to DB
# Sector : Consumer Discretionary, Ticker : MGM - Saved to DB
# Sector : Consumer Discretionary, Ticker : MHK - Saved to DB
# Sector : Consumer Discretionary, Ticker : NKE - Saved to DB
# Sector : Consumer Discretionary, Ticker : NCLH - Saved to DB
# Sector : Consumer Discretionary, Ticker : NVR - Saved to DB
# Sector : Consumer Discretionary, Ticker : ORLY - Saved to DB
# Sector : Consumer Discretionary, Ticker : POOL - Saved to DB
# Sector : Consumer Discretionary, Ticker : PHM - Saved to DB
# Sector : Consumer Discretionary, Ticker : RL - Saved to DB
# Sector : Consumer Discretionary, Ticker : ROST - Saved to DB
# Sector : Consumer Discretionary, Ticker : RCL - Saved to DB
# Sector : Consumer Discretionary, Ticker : SBUX - Saved to DB
# Sector : Consumer Discretionary, Ticker : TPR - Saved to DB
# Sector : Consumer Discretionary, Ticker : TSLA - Saved to DB
# Sector : Consumer Discretionary, Ticker : TJX - Saved to DB
# Sector : Consumer Discretionary, Ticker : TSCO - Saved to DB
# Sector : Consumer Discretionary, Ticker : ULTA - Saved to DB
# Sector : Consumer Discretionary, Ticker : WYNN - Saved to DB
# Sector : Consumer Discretionary, Ticker : YUM - Saved to DB
# [*********************100%***********************]  38 of 38 completed
#
# 1 Failed download:
# ['BF.B']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2010-01-01 -> 2024-12-17)')
# Sector : Consumer Staples, Ticker : MO - Saved to DB
# Sector : Consumer Staples, Ticker : ADM - Saved to DB
# Sector : Consumer Staples, Ticker : BG - Saved to DB
# Sector : Consumer Staples, Ticker : CPB - Saved to DB
# Sector : Consumer Staples, Ticker : CHD - Saved to DB
# Sector : Consumer Staples, Ticker : CLX - Saved to DB
# Sector : Consumer Staples, Ticker : KO - Saved to DB
# Sector : Consumer Staples, Ticker : CL - Saved to DB
# Sector : Consumer Staples, Ticker : CAG - Saved to DB
# Sector : Consumer Staples, Ticker : STZ - Saved to DB
# Sector : Consumer Staples, Ticker : COST - Saved to DB
# Sector : Consumer Staples, Ticker : DG - Saved to DB
# Sector : Consumer Staples, Ticker : DLTR - Saved to DB
# Sector : Consumer Staples, Ticker : EL - Saved to DB
# Sector : Consumer Staples, Ticker : GIS - Saved to DB
# Sector : Consumer Staples, Ticker : HSY - Saved to DB
# Sector : Consumer Staples, Ticker : HRL - Saved to DB
# Sector : Consumer Staples, Ticker : K - Saved to DB
# Sector : Consumer Staples, Ticker : KVUE - Saved to DB
# Sector : Consumer Staples, Ticker : KDP - Saved to DB
# Sector : Consumer Staples, Ticker : KMB - Saved to DB
# Sector : Consumer Staples, Ticker : KHC - Saved to DB
# Sector : Consumer Staples, Ticker : KR - Saved to DB
# Sector : Consumer Staples, Ticker : LW - Saved to DB
# Sector : Consumer Staples, Ticker : MKC - Saved to DB
# Sector : Consumer Staples, Ticker : TAP - Saved to DB
# Sector : Consumer Staples, Ticker : MDLZ - Saved to DB
# Sector : Consumer Staples, Ticker : MNST - Saved to DB
# Sector : Consumer Staples, Ticker : PEP - Saved to DB
# Sector : Consumer Staples, Ticker : PM - Saved to DB
# Sector : Consumer Staples, Ticker : PG - Saved to DB
# Sector : Consumer Staples, Ticker : SJM - Saved to DB
# Sector : Consumer Staples, Ticker : SYY - Saved to DB
# Sector : Consumer Staples, Ticker : TGT - Saved to DB
# Sector : Consumer Staples, Ticker : TSN - Saved to DB
# Sector : Consumer Staples, Ticker : WBA - Saved to DB
# Sector : Consumer Staples, Ticker : WMT - Saved to DB
# [*********************100%***********************]  22 of 22 completed
# Sector : Energy, Ticker : APA - Saved to DB
# Sector : Energy, Ticker : BKR - Saved to DB
# Sector : Energy, Ticker : CVX - Saved to DB
# Sector : Energy, Ticker : COP - Saved to DB
# Sector : Energy, Ticker : CTRA - Saved to DB
# Sector : Energy, Ticker : DVN - Saved to DB
# Sector : Energy, Ticker : FANG - Saved to DB
# Sector : Energy, Ticker : EOG - Saved to DB
# Sector : Energy, Ticker : EQT - Saved to DB
# Sector : Energy, Ticker : XOM - Saved to DB
# Sector : Energy, Ticker : HAL - Saved to DB
# Sector : Energy, Ticker : HES - Saved to DB
# Sector : Energy, Ticker : KMI - Saved to DB
# Sector : Energy, Ticker : MPC - Saved to DB
# Sector : Energy, Ticker : OXY - Saved to DB
# Sector : Energy, Ticker : OKE - Saved to DB
# Sector : Energy, Ticker : PSX - Saved to DB
# Sector : Energy, Ticker : SLB - Saved to DB
# Sector : Energy, Ticker : TRGP - Saved to DB
# Sector : Energy, Ticker : TPL - Saved to DB
# Sector : Energy, Ticker : VLO - Saved to DB
# Sector : Energy, Ticker : WMB - Saved to DB
# [*********************100%***********************]  72 of 72 completed
#
# 1 Failed download:
# ['BRK.B']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# Sector : Financials, Ticker : AFL - Saved to DB
# Sector : Financials, Ticker : ALL - Saved to DB
# Sector : Financials, Ticker : AXP - Saved to DB
# Sector : Financials, Ticker : AIG - Saved to DB
# Sector : Financials, Ticker : AMP - Saved to DB
# Sector : Financials, Ticker : AON - Saved to DB
# Sector : Financials, Ticker : ACGL - Saved to DB
# Sector : Financials, Ticker : AJG - Saved to DB
# Sector : Financials, Ticker : AIZ - Saved to DB
# Sector : Financials, Ticker : BAC - Saved to DB
# Sector : Financials, Ticker : BLK - Saved to DB
# Sector : Financials, Ticker : BX - Saved to DB
# Sector : Financials, Ticker : BK - Saved to DB
# Sector : Financials, Ticker : BRO - Saved to DB
# Sector : Financials, Ticker : COF - Saved to DB
# Sector : Financials, Ticker : CBOE - Saved to DB
# Sector : Financials, Ticker : SCHW - Saved to DB
# Sector : Financials, Ticker : CB - Saved to DB
# Sector : Financials, Ticker : CINF - Saved to DB
# Sector : Financials, Ticker : C - Saved to DB
# Sector : Financials, Ticker : CFG - Saved to DB
# Sector : Financials, Ticker : CME - Saved to DB
# Sector : Financials, Ticker : CPAY - Saved to DB
# Sector : Financials, Ticker : DFS - Saved to DB
# Sector : Financials, Ticker : ERIE - Saved to DB
# Sector : Financials, Ticker : EG - Saved to DB
# Sector : Financials, Ticker : FDS - Saved to DB
# Sector : Financials, Ticker : FIS - Saved to DB
# Sector : Financials, Ticker : FITB - Saved to DB
# Sector : Financials, Ticker : FI - Saved to DB
# Sector : Financials, Ticker : BEN - Saved to DB
# Sector : Financials, Ticker : GPN - Saved to DB
# Sector : Financials, Ticker : GL - Saved to DB
# Sector : Financials, Ticker : GS - Saved to DB
# Sector : Financials, Ticker : HIG - Saved to DB
# Sector : Financials, Ticker : HBAN - Saved to DB
# Sector : Financials, Ticker : ICE - Saved to DB
# Sector : Financials, Ticker : IVZ - Saved to DB
# Sector : Financials, Ticker : JKHY - Saved to DB
# Sector : Financials, Ticker : JPM - Saved to DB
# Sector : Financials, Ticker : KEY - Saved to DB
# Sector : Financials, Ticker : KKR - Saved to DB
# Sector : Financials, Ticker : L - Saved to DB
# Sector : Financials, Ticker : MTB - Saved to DB
# Sector : Financials, Ticker : MKTX - Saved to DB
# Sector : Financials, Ticker : MMC - Saved to DB
# Sector : Financials, Ticker : MA - Saved to DB
# Sector : Financials, Ticker : MET - Saved to DB
# Sector : Financials, Ticker : MCO - Saved to DB
# Sector : Financials, Ticker : MS - Saved to DB
# Sector : Financials, Ticker : MSCI - Saved to DB
# Sector : Financials, Ticker : NDAQ - Saved to DB
# Sector : Financials, Ticker : NTRS - Saved to DB
# Sector : Financials, Ticker : PYPL - Saved to DB
# Sector : Financials, Ticker : PNC - Saved to DB
# Sector : Financials, Ticker : PFG - Saved to DB
# Sector : Financials, Ticker : PGR - Saved to DB
# Sector : Financials, Ticker : PRU - Saved to DB
# Sector : Financials, Ticker : RJF - Saved to DB
# Sector : Financials, Ticker : RF - Saved to DB
# Sector : Financials, Ticker : SPGI - Saved to DB
# Sector : Financials, Ticker : STT - Saved to DB
# Sector : Financials, Ticker : SYF - Saved to DB
# Sector : Financials, Ticker : TROW - Saved to DB
# Sector : Financials, Ticker : TRV - Saved to DB
# Sector : Financials, Ticker : TFC - Saved to DB
# Sector : Financials, Ticker : USB - Saved to DB
# Sector : Financials, Ticker : V - Saved to DB
# Sector : Financials, Ticker : WRB - Saved to DB
# Sector : Financials, Ticker : WFC - Saved to DB
# Sector : Financials, Ticker : WTW - Saved to DB
# [*********************100%***********************]  62 of 62 completed
# Sector : Health Care, Ticker : ABT - Saved to DB
# Sector : Health Care, Ticker : ABBV - Saved to DB
# Sector : Health Care, Ticker : A - Saved to DB
# Sector : Health Care, Ticker : ALGN - Saved to DB
# Sector : Health Care, Ticker : AMGN - Saved to DB
# Sector : Health Care, Ticker : BAX - Saved to DB
# Sector : Health Care, Ticker : BDX - Saved to DB
# Sector : Health Care, Ticker : TECH - Saved to DB
# Sector : Health Care, Ticker : BIIB - Saved to DB
# Sector : Health Care, Ticker : BSX - Saved to DB
# Sector : Health Care, Ticker : BMY - Saved to DB
# Sector : Health Care, Ticker : CAH - Saved to DB
# Sector : Health Care, Ticker : CTLT - Saved to DB
# Sector : Health Care, Ticker : COR - Saved to DB
# Sector : Health Care, Ticker : CNC - Saved to DB
# Sector : Health Care, Ticker : CRL - Saved to DB
# Sector : Health Care, Ticker : CI - Saved to DB
# Sector : Health Care, Ticker : COO - Saved to DB
# Sector : Health Care, Ticker : CVS - Saved to DB
# Sector : Health Care, Ticker : DHR - Saved to DB
# Sector : Health Care, Ticker : DVA - Saved to DB
# Sector : Health Care, Ticker : DXCM - Saved to DB
# Sector : Health Care, Ticker : EW - Saved to DB
# Sector : Health Care, Ticker : ELV - Saved to DB
# Sector : Health Care, Ticker : GEHC - Saved to DB
# Sector : Health Care, Ticker : GILD - Saved to DB
# Sector : Health Care, Ticker : HCA - Saved to DB
# Sector : Health Care, Ticker : HSIC - Saved to DB
# Sector : Health Care, Ticker : HOLX - Saved to DB
# Sector : Health Care, Ticker : HUM - Saved to DB
# Sector : Health Care, Ticker : IDXX - Saved to DB
# Sector : Health Care, Ticker : INCY - Saved to DB
# Sector : Health Care, Ticker : PODD - Saved to DB
# Sector : Health Care, Ticker : ISRG - Saved to DB
# Sector : Health Care, Ticker : IQV - Saved to DB
# Sector : Health Care, Ticker : JNJ - Saved to DB
# Sector : Health Care, Ticker : LH - Saved to DB
# Sector : Health Care, Ticker : LLY - Saved to DB
# Sector : Health Care, Ticker : MCK - Saved to DB
# Sector : Health Care, Ticker : MDT - Saved to DB
# Sector : Health Care, Ticker : MRK - Saved to DB
# Sector : Health Care, Ticker : MTD - Saved to DB
# Sector : Health Care, Ticker : MRNA - Saved to DB
# Sector : Health Care, Ticker : MOH - Saved to DB
# Sector : Health Care, Ticker : PFE - Saved to DB
# Sector : Health Care, Ticker : DGX - Saved to DB
# Sector : Health Care, Ticker : REGN - Saved to DB
# Sector : Health Care, Ticker : RMD - Saved to DB
# Sector : Health Care, Ticker : RVTY - Saved to DB
# Sector : Health Care, Ticker : SOLV - Saved to DB
# Sector : Health Care, Ticker : STE - Saved to DB
# Sector : Health Care, Ticker : SYK - Saved to DB
# Sector : Health Care, Ticker : TFX - Saved to DB
# Sector : Health Care, Ticker : TMO - Saved to DB
# Sector : Health Care, Ticker : UNH - Saved to DB
# Sector : Health Care, Ticker : UHS - Saved to DB
# Sector : Health Care, Ticker : VRTX - Saved to DB
# Sector : Health Care, Ticker : VTRS - Saved to DB
# Sector : Health Care, Ticker : WAT - Saved to DB
# Sector : Health Care, Ticker : WST - Saved to DB
# Sector : Health Care, Ticker : ZBH - Saved to DB
# Sector : Health Care, Ticker : ZTS - Saved to DB
# [*********************100%***********************]  78 of 78 completed
# Sector : Industrials, Ticker : MMM - Saved to DB
# Sector : Industrials, Ticker : AOS - Saved to DB
# Sector : Industrials, Ticker : ALLE - Saved to DB
# Sector : Industrials, Ticker : AMTM - Saved to DB
# Sector : Industrials, Ticker : AME - Saved to DB
# Sector : Industrials, Ticker : ADP - Saved to DB
# Sector : Industrials, Ticker : AXON - Saved to DB
# Sector : Industrials, Ticker : BA - Saved to DB
# Sector : Industrials, Ticker : BR - Saved to DB
# Sector : Industrials, Ticker : BLDR - Saved to DB
# Sector : Industrials, Ticker : CHRW - Saved to DB
# Sector : Industrials, Ticker : CARR - Saved to DB
# Sector : Industrials, Ticker : CAT - Saved to DB
# Sector : Industrials, Ticker : CTAS - Saved to DB
# Sector : Industrials, Ticker : CPRT - Saved to DB
# Sector : Industrials, Ticker : CSX - Saved to DB
# Sector : Industrials, Ticker : CMI - Saved to DB
# Sector : Industrials, Ticker : DAY - Saved to DB
# Sector : Industrials, Ticker : DE - Saved to DB
# Sector : Industrials, Ticker : DAL - Saved to DB
# Sector : Industrials, Ticker : DOV - Saved to DB
# Sector : Industrials, Ticker : ETN - Saved to DB
# Sector : Industrials, Ticker : EMR - Saved to DB
# Sector : Industrials, Ticker : EFX - Saved to DB
# Sector : Industrials, Ticker : EXPD - Saved to DB
# Sector : Industrials, Ticker : FAST - Saved to DB
# Sector : Industrials, Ticker : FDX - Saved to DB
# Sector : Industrials, Ticker : FTV - Saved to DB
# Sector : Industrials, Ticker : GE - Saved to DB
# Sector : Industrials, Ticker : GEV - Saved to DB
# Sector : Industrials, Ticker : GNRC - Saved to DB
# Sector : Industrials, Ticker : GD - Saved to DB
# Sector : Industrials, Ticker : HON - Saved to DB
# Sector : Industrials, Ticker : HWM - Saved to DB
# Sector : Industrials, Ticker : HUBB - Saved to DB
# Sector : Industrials, Ticker : HII - Saved to DB
# Sector : Industrials, Ticker : IEX - Saved to DB
# Sector : Industrials, Ticker : ITW - Saved to DB
# Sector : Industrials, Ticker : IR - Saved to DB
# Sector : Industrials, Ticker : JBHT - Saved to DB
# Sector : Industrials, Ticker : J - Saved to DB
# Sector : Industrials, Ticker : JCI - Saved to DB
# Sector : Industrials, Ticker : LHX - Saved to DB
# Sector : Industrials, Ticker : LDOS - Saved to DB
# Sector : Industrials, Ticker : LMT - Saved to DB
# Sector : Industrials, Ticker : MAS - Saved to DB
# Sector : Industrials, Ticker : NDSN - Saved to DB
# Sector : Industrials, Ticker : NSC - Saved to DB
# Sector : Industrials, Ticker : NOC - Saved to DB
# Sector : Industrials, Ticker : ODFL - Saved to DB
# Sector : Industrials, Ticker : OTIS - Saved to DB
# Sector : Industrials, Ticker : PCAR - Saved to DB
# Sector : Industrials, Ticker : PH - Saved to DB
# Sector : Industrials, Ticker : PAYX - Saved to DB
# Sector : Industrials, Ticker : PAYC - Saved to DB
# Sector : Industrials, Ticker : PNR - Saved to DB
# Sector : Industrials, Ticker : PWR - Saved to DB
# Sector : Industrials, Ticker : RTX - Saved to DB
# Sector : Industrials, Ticker : RSG - Saved to DB
# Sector : Industrials, Ticker : ROK - Saved to DB
# Sector : Industrials, Ticker : ROL - Saved to DB
# Sector : Industrials, Ticker : SNA - Saved to DB
# Sector : Industrials, Ticker : LUV - Saved to DB
# Sector : Industrials, Ticker : SWK - Saved to DB
# Sector : Industrials, Ticker : TXT - Saved to DB
# Sector : Industrials, Ticker : TT - Saved to DB
# Sector : Industrials, Ticker : TDG - Saved to DB
# Sector : Industrials, Ticker : UBER - Saved to DB
# Sector : Industrials, Ticker : UNP - Saved to DB
# Sector : Industrials, Ticker : UAL - Saved to DB
# Sector : Industrials, Ticker : UPS - Saved to DB
# Sector : Industrials, Ticker : URI - Saved to DB
# Sector : Industrials, Ticker : VLTO - Saved to DB
# Sector : Industrials, Ticker : VRSK - Saved to DB
# Sector : Industrials, Ticker : GWW - Saved to DB
# Sector : Industrials, Ticker : WAB - Saved to DB
# Sector : Industrials, Ticker : WM - Saved to DB
# Sector : Industrials, Ticker : XYL - Saved to DB
# [*********************100%***********************]  69 of 69 completed
# Sector : Information Technology, Ticker : ACN - Saved to DB
# Sector : Information Technology, Ticker : ADBE - Saved to DB
# Sector : Information Technology, Ticker : AMD - Saved to DB
# Sector : Information Technology, Ticker : AKAM - Saved to DB
# Sector : Information Technology, Ticker : APH - Saved to DB
# Sector : Information Technology, Ticker : ADI - Saved to DB
# Sector : Information Technology, Ticker : ANSS - Saved to DB
# Sector : Information Technology, Ticker : AAPL - Saved to DB
# Sector : Information Technology, Ticker : AMAT - Saved to DB
# Sector : Information Technology, Ticker : ANET - Saved to DB
# Sector : Information Technology, Ticker : ADSK - Saved to DB
# Sector : Information Technology, Ticker : AVGO - Saved to DB
# Sector : Information Technology, Ticker : CDNS - Saved to DB
# Sector : Information Technology, Ticker : CDW - Saved to DB
# Sector : Information Technology, Ticker : CSCO - Saved to DB
# Sector : Information Technology, Ticker : CTSH - Saved to DB
# Sector : Information Technology, Ticker : GLW - Saved to DB
# Sector : Information Technology, Ticker : CRWD - Saved to DB
# Sector : Information Technology, Ticker : DELL - Saved to DB
# Sector : Information Technology, Ticker : ENPH - Saved to DB
# Sector : Information Technology, Ticker : EPAM - Saved to DB
# Sector : Information Technology, Ticker : FFIV - Saved to DB
# Sector : Information Technology, Ticker : FICO - Saved to DB
# Sector : Information Technology, Ticker : FSLR - Saved to DB
# Sector : Information Technology, Ticker : FTNT - Saved to DB
# Sector : Information Technology, Ticker : IT - Saved to DB
# Sector : Information Technology, Ticker : GEN - Saved to DB
# Sector : Information Technology, Ticker : GDDY - Saved to DB
# Sector : Information Technology, Ticker : HPE - Saved to DB
# Sector : Information Technology, Ticker : HPQ - Saved to DB
# Sector : Information Technology, Ticker : IBM - Saved to DB
# Sector : Information Technology, Ticker : INTC - Saved to DB
# Sector : Information Technology, Ticker : INTU - Saved to DB
# Sector : Information Technology, Ticker : JBL - Saved to DB
# Sector : Information Technology, Ticker : JNPR - Saved to DB
# Sector : Information Technology, Ticker : KEYS - Saved to DB
# Sector : Information Technology, Ticker : KLAC - Saved to DB
# Sector : Information Technology, Ticker : LRCX - Saved to DB
# Sector : Information Technology, Ticker : MCHP - Saved to DB
# Sector : Information Technology, Ticker : MU - Saved to DB
# Sector : Information Technology, Ticker : MSFT - Saved to DB
# Sector : Information Technology, Ticker : MPWR - Saved to DB
# Sector : Information Technology, Ticker : MSI - Saved to DB
# Sector : Information Technology, Ticker : NTAP - Saved to DB
# Sector : Information Technology, Ticker : NVDA - Saved to DB
# Sector : Information Technology, Ticker : NXPI - Saved to DB
# Sector : Information Technology, Ticker : ON - Saved to DB
# Sector : Information Technology, Ticker : ORCL - Saved to DB
# Sector : Information Technology, Ticker : PLTR - Saved to DB
# Sector : Information Technology, Ticker : PANW - Saved to DB
# Sector : Information Technology, Ticker : PTC - Saved to DB
# Sector : Information Technology, Ticker : QRVO - Saved to DB
# Sector : Information Technology, Ticker : QCOM - Saved to DB
# Sector : Information Technology, Ticker : ROP - Saved to DB
# Sector : Information Technology, Ticker : CRM - Saved to DB
# Sector : Information Technology, Ticker : STX - Saved to DB
# Sector : Information Technology, Ticker : NOW - Saved to DB
# Sector : Information Technology, Ticker : SWKS - Saved to DB
# Sector : Information Technology, Ticker : SMCI - Saved to DB
# Sector : Information Technology, Ticker : SNPS - Saved to DB
# Sector : Information Technology, Ticker : TEL - Saved to DB
# Sector : Information Technology, Ticker : TDY - Saved to DB
# Sector : Information Technology, Ticker : TER - Saved to DB
# Sector : Information Technology, Ticker : TXN - Saved to DB
# Sector : Information Technology, Ticker : TRMB - Saved to DB
# Sector : Information Technology, Ticker : TYL - Saved to DB
# Sector : Information Technology, Ticker : VRSN - Saved to DB
# Sector : Information Technology, Ticker : WDC - Saved to DB
# Sector : Information Technology, Ticker : ZBRA - Saved to DB
# [*********************100%***********************]  28 of 28 completed
# Sector : Materials, Ticker : APD - Saved to DB
# Sector : Materials, Ticker : ALB - Saved to DB
# Sector : Materials, Ticker : AMCR - Saved to DB
# Sector : Materials, Ticker : AVY - Saved to DB
# Sector : Materials, Ticker : BALL - Saved to DB
# Sector : Materials, Ticker : CE - Saved to DB
# Sector : Materials, Ticker : CF - Saved to DB
# Sector : Materials, Ticker : CTVA - Saved to DB
# Sector : Materials, Ticker : DOW - Saved to DB
# Sector : Materials, Ticker : DD - Saved to DB
# Sector : Materials, Ticker : EMN - Saved to DB
# Sector : Materials, Ticker : ECL - Saved to DB
# Sector : Materials, Ticker : FMC - Saved to DB
# Sector : Materials, Ticker : FCX - Saved to DB
# Sector : Materials, Ticker : IFF - Saved to DB
# Sector : Materials, Ticker : IP - Saved to DB
# Sector : Materials, Ticker : LIN - Saved to DB
# Sector : Materials, Ticker : LYB - Saved to DB
# Sector : Materials, Ticker : MLM - Saved to DB
# Sector : Materials, Ticker : MOS - Saved to DB
# Sector : Materials, Ticker : NEM - Saved to DB
# Sector : Materials, Ticker : NUE - Saved to DB
# Sector : Materials, Ticker : PKG - Saved to DB
# Sector : Materials, Ticker : PPG - Saved to DB
# Sector : Materials, Ticker : SHW - Saved to DB
# Sector : Materials, Ticker : SW - Saved to DB
# Sector : Materials, Ticker : STLD - Saved to DB
# Sector : Materials, Ticker : VMC - Saved to DB
# [*********************100%***********************]  31 of 31 completed
# Sector : Real Estate, Ticker : ARE - Saved to DB
# Sector : Real Estate, Ticker : AMT - Saved to DB
# Sector : Real Estate, Ticker : AVB - Saved to DB
# Sector : Real Estate, Ticker : BXP - Saved to DB
# Sector : Real Estate, Ticker : CPT - Saved to DB
# Sector : Real Estate, Ticker : CBRE - Saved to DB
# Sector : Real Estate, Ticker : CSGP - Saved to DB
# Sector : Real Estate, Ticker : CCI - Saved to DB
# Sector : Real Estate, Ticker : DLR - Saved to DB
# Sector : Real Estate, Ticker : EQIX - Saved to DB
# Sector : Real Estate, Ticker : EQR - Saved to DB
# Sector : Real Estate, Ticker : ESS - Saved to DB
# Sector : Real Estate, Ticker : EXR - Saved to DB
# Sector : Real Estate, Ticker : FRT - Saved to DB
# Sector : Real Estate, Ticker : DOC - Saved to DB
# Sector : Real Estate, Ticker : HST - Saved to DB
# Sector : Real Estate, Ticker : INVH - Saved to DB
# Sector : Real Estate, Ticker : IRM - Saved to DB
# Sector : Real Estate, Ticker : KIM - Saved to DB
# Sector : Real Estate, Ticker : MAA - Saved to DB
# Sector : Real Estate, Ticker : PLD - Saved to DB
# Sector : Real Estate, Ticker : PSA - Saved to DB
# Sector : Real Estate, Ticker : O - Saved to DB
# Sector : Real Estate, Ticker : REG - Saved to DB
# Sector : Real Estate, Ticker : SBAC - Saved to DB
# Sector : Real Estate, Ticker : SPG - Saved to DB
# Sector : Real Estate, Ticker : UDR - Saved to DB
# Sector : Real Estate, Ticker : VTR - Saved to DB
# Sector : Real Estate, Ticker : VICI - Saved to DB
# Sector : Real Estate, Ticker : WELL - Saved to DB
# Sector : Real Estate, Ticker : WY - Saved to DB
# [*********************100%***********************]  31 of 31 completed
# Sector : Utilities, Ticker : AES - Saved to DB
# Sector : Utilities, Ticker : LNT - Saved to DB
# Sector : Utilities, Ticker : AEE - Saved to DB
# Sector : Utilities, Ticker : AEP - Saved to DB
# Sector : Utilities, Ticker : AWK - Saved to DB
# Sector : Utilities, Ticker : ATO - Saved to DB
# Sector : Utilities, Ticker : CNP - Saved to DB
# Sector : Utilities, Ticker : CMS - Saved to DB
# Sector : Utilities, Ticker : ED - Saved to DB
# Sector : Utilities, Ticker : CEG - Saved to DB
# Sector : Utilities, Ticker : D - Saved to DB
# Sector : Utilities, Ticker : DTE - Saved to DB
# Sector : Utilities, Ticker : DUK - Saved to DB
# Sector : Utilities, Ticker : EIX - Saved to DB
# Sector : Utilities, Ticker : ETR - Saved to DB
# Sector : Utilities, Ticker : EVRG - Saved to DB
# Sector : Utilities, Ticker : ES - Saved to DB
# Sector : Utilities, Ticker : EXC - Saved to DB
# Sector : Utilities, Ticker : FE - Saved to DB
# Sector : Utilities, Ticker : NEE - Saved to DB
# Sector : Utilities, Ticker : NI - Saved to DB
# Sector : Utilities, Ticker : NRG - Saved to DB
# Sector : Utilities, Ticker : PCG - Saved to DB
# Sector : Utilities, Ticker : PNW - Saved to DB
# Sector : Utilities, Ticker : PPL - Saved to DB
# Sector : Utilities, Ticker : PEG - Saved to DB
# Sector : Utilities, Ticker : SRE - Saved to DB
# Sector : Utilities, Ticker : SO - Saved to DB
# Sector : Utilities, Ticker : VST - Saved to DB
# Sector : Utilities, Ticker : WEC - Saved to DB
# Sector : Utilities, Ticker : XEL - Saved to DB

# %%
'''
DB의 데이터 확인
'''
import sqlite3
import pandas as pd


conn = sqlite3.connect('Database/S&P500.db')
query = "SELECT * FROM daily_stock_price;"
daily_stock_price = pd.read_sql_query(query, conn)
conn.close()
display(daily_stock_price)
